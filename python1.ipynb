# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratikshapawar-star/python-internship-practice-code/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
print("Types of a: ", type(a))

b=5.0
print("\nTypes of b: ", type(b))

c=2+4j
print("\nTypes of c: ", type(c))
# Out:
# Types of a:  <class 'int'>
#
# Types of b:  <class 'float'>
#
# Types of c:  <class 'complex'>

# %%
# using input() to take user input
num=input('Enter a number: ')
print('You Entered: ', num)
print('Data type of num:', type(num))
# Out:
# Enter a number: 51
# You Entered:  51
# Data type of num: <class 'str'>
