# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratikshapawar-star/python-internship-practice-code/blob/main/Day7_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

# %%
# Splitting the dataset into the training and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.7,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,regressor.predict(x_train),color="blue")

# %%
plt.scatter(x_test,y_test,color="red")
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.title("Salary va Experience (Test set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
import joblib
#save the model to file
joblib.dump(regressor,"Prediction of the salary.pkl")
# Out:
# ['Prediction of the salary.pkl']

# %%
# @title Default title text
# Step 4: Live prediction
while True:
    try:
        # Get user input
        years_of_experience = float(input("Enter Years of Experience (or type 'exit' to quit): "))

        # Predict the salary
        predicted_salary = regressor.predict([[years_of_experience]])[0]  # Model expects 2D array
        print(f"Predicted Salary for {years_of_experience} years of experience: ${predicted_salary:.2f}")
    except ValueError:
        print("Exiting...")
        break
# Out:
# Enter Years of Experience (or type 'exit' to quit): 1.5
# Predicted Salary for 1.5 years of experience: $39309.27
# Enter Years of Experience (or type 'exit' to quit): 22
# Predicted Salary for 22.0 years of experience: $235668.37
# Enter Years of Experience (or type 'exit' to quit): exit
# Exiting...

# %% [markdown]
# Appliance Energy

# %%
dataf=pd.read_csv("appliance_energy.csv")
dataf.head()
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
dataf.shape
# Out:
# (100, 2)

# %%
x=dataf[["Temperature (°C)"]]
y=dataf["Energy Consumption (kWh)"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Create a Linear Regression model
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model=.predict(x_test)

# %%
y_pred
# Out:
# array([ 39309.27209624, 123600.00845907,  64213.35329435,  62297.65474065,
#        115937.21424426, 108274.42002946, 116895.06352111,  63255.5040175 ,
#         75707.54461655, 100611.62581466,  52719.16197215,  73791.84606285,
#         55592.7098027 ,  68044.75040175, 103485.17364521,  90075.28376931,
#         37393.57354254, 125515.70701277,  53677.011249  ,  46014.21703419,
#         81454.64027765])

# %%
from sklearn_metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error:{mse}")

r2 = r2_score(y_test, y_pred)
print(f"R-squared:{r2}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2351067460.py in <cell line: 0>()
# ----> 1 from sklearn_metrics import mean_squared_error,r2_score
#       2 mse = mean_squared_error(y_test, y_pred)
#       3 print(f"Mean Squared Error:{mse}")
#       4
#       5 r2 = r2_score(y_test, y_pred)
#
# ModuleNotFoundError: No module named 'sklearn_metrics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
plt.scatter(x_test,y_test,color="blue",label="Test data")
plt.plot(x_test,y_pred,color="red", lable="Regression Line")
plt.xlabel("Temperature (°C)")
plt.ylabel("Energy Consumption (kWh)")
plt.legend()
plt.title("Energy Consumption Prediction using Simple Linear regression")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-427724152.py in <cell line: 0>()
# ----> 1 plt.scatter(x_test,y_test,color="blue",label="Test data")
#       2 plt.plot(x_test,y_pred,color="red", lable="Regression Line")
#       3 plt.xlabel("Temperature (°C)")
#       4 plt.ylabel("Energy Consumption (kWh)")
#       5 plt.legend()
#
# NameError: name 'plt' is not defined

# %%
import joblib
joblib.dmp(model,"appliance_energy_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3010833073.py in <cell line: 0>()
#       1 import joblib
# ----> 2 joblib.dmp(model,"appliance_energy_model.pkl")
#
# AttributeError: module 'joblib' has no attribute 'dmp'

# %%
data=pd.read_csv("data.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3401253009.py in <cell line: 0>()
# ----> 1 data=pd.read_csv("data.csv")
#       2 data.head()
#
# NameError: name 'pd' is not defined

# %%
x=data.iloc[:,0:3].values
y=data.iloc[:,-1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2491749361.py in <cell line: 0>()
# ----> 1 x=data.iloc[:,0:3].values
#       2 y=data.iloc[:,-1].values
#
# NameError: name 'data' is not defined

# %%
x
# Out:
# array([[-5.70562824e-01,  1.42034231e+00,  4.95580395e-01],
#        [-9.90562704e-01,  5.56964528e-01,  1.04506399e+00],
#        [-6.74727510e-01,  1.50616865e-01,  1.77464503e+00],
#        [ 3.88250414e-01, -3.87127181e-01, -1.10229155e-01],
#        [ 1.16788229e+00, -2.41044701e-02,  1.45063214e-01],
#        [-8.89888979e-01, -1.58094538e+00, -4.22792727e-01],
#        [-2.68510868e+00,  1.84207947e-02,  1.72266920e+00],
#        [ 6.63187770e-01,  1.85267835e-01, -1.88342383e+00],
#        [ 3.19196176e-01, -2.98397020e+00, -1.51521566e+00],
#        [-3.48368316e-01, -1.81101917e+00,  7.46891531e-01],
#        [-6.37134863e-01, -5.39574612e-01, -4.08345242e-01],
#        [ 1.11594518e+00, -3.03033672e-02, -3.19590141e-01],
#        [-6.89599657e-01, -3.57440729e-01, -5.41503716e-01],
#        [ 2.07087853e+00,  1.06979836e+00,  5.93588115e-01],
#        [-7.12849796e-01, -1.50891712e+00, -2.52815988e-01],
#        [ 8.87925723e-01, -8.23886105e-01,  4.36232115e-01],
# ...

# %%
y
# Out:
# array([  -9.76318213,  -24.02935493,   45.61642069,   34.13573658,
#          86.66364674,  -77.89735638,  -75.23160582,  -57.49271113,
#         -54.17628622,   29.46983531,  -87.07697894,   61.49707765,
#         -87.1908553 ,  189.52586717, -105.60940906,   72.93452847,
#          33.37559704, -108.0026368 , -127.03270151,  -97.32244317,
#         -56.51293004,  -61.6929032 ,  -46.54502761,  -55.46277415,
#          98.27590634,   53.88321804,  -69.66191612,  143.07902342,
#        -114.61997528,   31.85127955,  -44.39024034,    1.48968394,
#         -88.71622065,   87.12681822,  -17.28585002,  150.20169579,
#         -71.41503479, -139.82571896,  190.13399327,  126.78997841,
#         191.14039956,  -15.88018358,   79.0476178 ,   32.44367679,
#          43.23159853,  -34.70291861,  -94.49899703,   92.90733739,
#         -49.79965934, -257.06342658,  -28.33835823,   52.78981793,
#        -114.24973574,   31.88367296,   80.14978081,   85.36236114,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-757456048.py in <cell line: 0>()
#       1 from sklearn.linear_model import LinearRegression
#       2 model=LinearRegression()
# ----> 3 model.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# 1.Linear relationship

# %%
fig,(ax1,ax2,ax3)=plt.subplots(ncols=3,figsize=(12,2.5))

ax1.scatter(data["feature1"], data["target"])
ax1.set_title("Feature1")
ax2.scatter(data["feature2"], data["target"])
ax2.set_title("Feature2")
ax3.scatter(data["feature3"], data["target"])
ax3.set_title("Feature3")

plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=[]

for i in range(x_train.shape[1]):
 vif.append(variance_inflation_factor(x_train, i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2596829565.py in <cell line: 0>()
#       3 vif=[]
#       4
# ----> 5 for i in range(x_train.shape[1]):
#       6  vif.append(variance_inflation_factor(x_train, i))
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# 2.Multicollinearity

# %%
pd.DataFrame({"vif":vif},index=df.columns[0:3]).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-422513318.py in <cell line: 0>()
# ----> 1 pd.DataFrame({"vif":vif},index=df.columns[0:3]).T
#
# NameError: name 'vif' is not defined

# %%
sns.heatmap(df.iloc[:,0:3].corr(),annot=True)

# %% [markdown]
# 3.Normality of Residual

# %%
sns.displot(residual, kind="kde")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2873008181.py in <cell line: 0>()
# ----> 1 sns.displot(residual, kind="kde")
#
# NameError: name 'residual' is not defined

# %% [markdown]
# QQ plot

# %%
#QQ plot

import scipy as sp
fig, ax = plt.subplots(figsize=(6,4))
sp.probplot(residual, plot=ax, fit=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/scipy/__init__.py in __getattr__(name)
#     133         try:
# --> 134             return globals()[name]
#     135         except KeyError:
#
# KeyError: 'probplot'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3872604269.py in <cell line: 0>()
#       3 import scipy as sp
#       4 fig, ax = plt.subplots(figsize=(6,4))
# ----> 5 sp.probplot(residual, plot=ax, fit=True)
#       6 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/scipy/__init__.py in __getattr__(name)
#     134             return globals()[name]
#     135         except KeyError:
# --> 136             raise AttributeError(
#     137                 f"Module 'scipy' has no attribute '{name}'"
# ...

# %% [markdown]
# 4.Homoscedasticity

# %%
plt.scatter(y_pred,residual)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4233600902.py in <cell line: 0>()
# ----> 1 plt.scatter(y_pred,residual)
#
# NameError: name 'residual' is not defined

# %% [markdown]
# 5. Autocorrelation of Residuals

# %%
plt.plot(residual)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1727810618.py in <cell line: 0>()
# ----> 1 plt.plot(residual)
#
# NameError: name 'residual' is not defined
